# %% [markdown]
# # Epidemiological Surveillance Dashboard
#
# **Data**: CDC WONDER — Multiple Cause of Death
# **Source**: https://wonder.cdc.gov/mcd-icd10.html
# **Records**: 3M+ deaths annually (1999-present)
# **Variables**: Cause of death (ICD-10), demographics, geography, year
#
# ## Objectives
# 1. Mortality trend analysis (1999-2024)
# 2. Opioid overdose epidemic trajectory
# 3. Geographic clustering of health disparities
# 4. Real-time surveillance simulation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.load_health_data import load_cdc_wonder_stub

# Load CDC WONDER mortality data
df = load_cdc_wonder_stub()
print(f'Shape: {df.shape}')
print(f'Columns: {df.columns.tolist()}')
df.head()

# %% [markdown]
# ## 1. Mortality Trends (1999-2024)

# %%
# TODO: Age-adjusted death rates by cause over time
# TODO: Identify inflection points (COVID-19, opioid crisis)

# %% [markdown]
# ## 2. Opioid Epidemic Trajectory

# %%
# TODO: T40.x overdose deaths by year and state
# TODO: Rt estimation (effective reproduction of overdose clusters)

# %% [markdown]
# ## 3. Geographic Disparity Analysis

# %%
# TODO: State-level age-adjusted rates choropleth
# TODO: Cluster analysis of high-burden counties

# %% [markdown]
# ## Executive Summary
#
# *Placeholder for analysis findings after data load.*
