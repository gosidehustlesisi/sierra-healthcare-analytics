# %% [markdown]
# # Medicaid Drug Utilization Dashboard
#
# **Data**: CMS State Drug Utilization Data (2019-2024)
# **Source**: https://data.cms.gov/summary-statistics-on-beneficiary-populations/medicare-and-medicaid-drug-spending-by-state
# **Records**: 50 states × 6 years × ~2,000 NDCs = ~600K records
#
# ## Objectives
# 1. State-level prescribing patterns
# 2. Generic vs brand penetration rates
# 3. Opioid utilization monitoring
# 4. Cost trend analysis by therapeutic class

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.load_health_data import load_cms_drug_utilization

# Load CMS Medicaid drug utilization data
df = load_cms_drug_utilization(year=2022)
print(f'Shape: {df.shape}')
print(f'Columns: {df.columns.tolist()}')
df.head()

# %% [markdown]
# ## 1. State-Level Prescribing Volume

# %%
# TODO: Aggregate by state, plot top 10 by total claims
# TODO: Choropleth map of prescribing rates per 1K beneficiaries

# %% [markdown]
# ## 2. Generic Penetration Analysis

# %%
# TODO: Calculate generic % by state and therapeutic class
# TODO: Identify states with low generic adoption

# %% [markdown]
# ## 3. Opioid Utilization Monitoring

# %%
# TODO: Filter to opioid NDCs, calculate MME per beneficiary
# TODO: Time series of opioid prescribing rates

# %% [markdown]
# ## Executive Summary
#
# *Placeholder for analysis findings after data load.*
